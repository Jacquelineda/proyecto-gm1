# %% [markdown]
# <a href="https://colab.research.google.com/github/Jacquelineda/proyecto-gm1/blob/master/Prueba.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
seconds_in_a_day = 24 * 60 * 60
seconds_in_a_day
# Out:
# 86400

# %% [markdown]
# *cursiva*
# **negrita**
# #encabezado
#
# lista numerada
# 1. Elemento
# 2. Elemento
# 3. elemento

# %%
# !pip install scipy

# %%
import numpy as np
from matplotlib import pyplot as plt

ys = 200 + np.random.randn(200)
x = [x for x in range(len(ys))]

plt.plot(x, ys, '-')
plt.fill_between(x, ys, 195, where=(ys > 195), facecolor='r', alpha=0.6)

plt.title("Sample Visualization")
plt.show()
